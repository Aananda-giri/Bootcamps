# %% [markdown]
# ## Semantic kernel
# - [microsoft/semantic-kernel](https://github.com/microsoft/semantic-kernel)
# - vs code also have extension for semantic kernel.

# %%
# !pip install semantic-kernel
# Out:
# Collecting semantic-kernel
#   Downloading semantic_kernel-1.26.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp~=3.8 (from semantic-kernel)
#   Using cached aiohttp-3.11.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting cloudevents~=1.0 (from semantic-kernel)
#   Downloading cloudevents-1.11.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0 (from semantic-kernel)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting pydantic-settings~=2.0 (from semantic-kernel)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting defusedxml~=0.7 (from semantic-kernel)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting azure-identity~=1.13 (from semantic-kernel)
#   Using cached azure_identity-1.21.0-py3-none-any.whl.metadata (81 kB)
# Collecting numpy>=1.26.0 (from semantic-kernel)
#   Using cached numpy-2.2.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting openai~=1.61 (from semantic-kernel)
#   Using cached openai-1.69.0-py3-none-any.whl.metadata (25 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<16,>=13 (from semantic-kernel)
#   Downloading websockets-15.0.1-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting aiortc>=1.9.0 (from semantic-kernel)
#   Downloading aiortc-1.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting opentelemetry-api~=1.24 (from semantic-kernel)
#   Using cached opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk~=1.24 (from semantic-kernel)
#   Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting prance~=23.6.21.0 (from semantic-kernel)
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic-kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jinja2~=3.1 (from semantic-kernel)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: nest-asyncio~=1.6 in /mnt/resources2/weekly-projects/learning/AI-Agents-In-Action/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.6.0)
# Collecting scipy>=1.15.1 (from semantic-kernel)
#   Downloading scipy-1.15.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting websockets<16,>=13 (from semantic-kernel)
#   Downloading websockets-14.2-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp~=3.8->semantic-kernel)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp~=3.8->semantic-kernel)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp~=3.8->semantic-kernel)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp~=3.8->semantic-kernel)
#   Using cached frozenlist-1.5.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp~=3.8->semantic-kernel)
#   Using cached multidict-6.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting propcache>=0.2.0 (from aiohttp~=3.8->semantic-kernel)
#   Using cached propcache-0.3.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp~=3.8->semantic-kernel)
#   Using cached yarl-1.18.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
# Collecting aioice<1.0.0,>=0.9.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading aioice-0.9.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting av<15.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading av-14.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Collecting cffi>=1.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading cffi-1.17.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Using cached cryptography-44.0.2-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting google-crc32c>=1.1 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading google_crc32c-1.7.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pylibsrtp-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic-kernel)
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting azure-core>=1.31.0 (from azure-identity~=1.13->semantic-kernel)
#   Using cached azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Collecting msal>=1.30.0 (from azure-identity~=1.13->semantic-kernel)
#   Using cached msal-1.32.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity~=1.13->semantic-kernel)
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting typing-extensions>=4.0.0 (from azure-identity~=1.13->semantic-kernel)
#   Using cached typing_extensions-4.13.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic-kernel)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2~=3.1->semantic-kernel)
#   Using cached MarkupSafe-3.0.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting anyio<5,>=3.5.0 (from openai~=1.61->semantic-kernel)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from openai~=1.61->semantic-kernel)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai~=1.61->semantic-kernel)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai~=1.61->semantic-kernel)
#   Using cached jiter-0.9.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai~=1.61->semantic-kernel)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai~=1.61->semantic-kernel)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api~=1.24->semantic-kernel)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-metadata<8.7.0,>=6.0 (from opentelemetry-api~=1.24->semantic-kernel)
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-semantic-conventions==0.52b1 (from opentelemetry-sdk~=1.24->semantic-kernel)
#   Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting chardet>=3.0 (from prance~=23.6.21.0->semantic-kernel)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance~=23.6.21.0->semantic-kernel)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Collecting requests>=2.25 (from prance~=23.6.21.0->semantic-kernel)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six~=1.15 in /mnt/resources2/weekly-projects/learning/AI-Agents-In-Action/.venv/lib/python3.13/site-packages (from prance~=23.6.21.0->semantic-kernel) (1.17.0)
# Requirement already satisfied: packaging>=21.3 in /mnt/resources2/weekly-projects/learning/AI-Agents-In-Action/.venv/lib/python3.13/site-packages (from prance~=23.6.21.0->semantic-kernel) (24.2)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic-kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting annotated-types>=0.6.0 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.11,>=2.0->semantic-kernel)
#   Using cached pydantic_core-2.27.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings~=2.0->semantic-kernel)
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.9.0->aiortc>=1.9.0->semantic-kernel)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai~=1.61->semantic-kernel)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting pycparser (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api~=1.24->semantic-kernel)
#   Using cached wrapt-1.17.2-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai~=1.61->semantic-kernel)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai~=1.61->semantic-kernel)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading rpds_py-0.24.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting PyYAML>=5.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Using cached PyYAML-6.0.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity~=1.13->semantic-kernel)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel)
#   Downloading lazy-object-proxy-1.10.0.tar.gz (43 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting charset-normalizer<4,>=2 (from requests>=2.25->prance~=23.6.21.0->semantic-kernel)
#   Using cached charset_normalizer-3.4.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25->prance~=23.6.21.0->semantic-kernel)
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Downloading semantic_kernel-1.26.1-py3-none-any.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 kB 993.0 kB/s eta 0:00:00a 0:00:01
# Using cached aiohttp-3.11.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Downloading aiortc-1.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.3 MB/s eta 0:00:00a 0:00:01
# Using cached azure_identity-1.21.0-py3-none-any.whl (189 kB)
# Downloading cloudevents-1.11.0-py3-none-any.whl (55 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached numpy-2.2.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
# Using cached openai-1.69.0-py3-none-any.whl (599 kB)
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
# Using cached opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
# Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl (183 kB)
# Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Downloading scipy-1.15.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 1.0 MB/s eta 0:00:0000:0100:01
# Downloading websockets-14.2-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (170 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aioice-0.9.0-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading av-14.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 1.1 MB/s eta 0:00:0000:0100:01
# Using cached azure_core-1.32.0-py3-none-any.whl (198 kB)
# Downloading cffi-1.17.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached cryptography-44.0.2-cp39-abi3-manylinux_2_34_x86_64.whl (4.2 MB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.5.0-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (267 kB)
# Downloading google_crc32c-1.7.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Using cached jiter-0.9.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Using cached MarkupSafe-3.0.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached msal-1.32.0-py3-none-any.whl (114 kB)
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached multidict-6.2.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Using cached propcache-0.3.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (228 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.13.0-py3-none-any.whl (45 kB)
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
# Using cached yarl-1.18.3-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (339 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading more_itertools-10.6.0-py3-none-any.whl (63 kB)
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached charset_normalizer-3.4.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (759 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.24.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (393 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Using cached wrapt-1.17.2-cp313-cp313-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Building wheels for collected packages: pybars4, PyMeta3, lazy-object-proxy
#   Building wheel for pybars4 (pyproject.toml) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14417 sha256=353419140490244e02751d73283fe4552cb5be7c2b04200d399ae30902676cf9
#   Stored in directory: /home/anon/.cache/pip/wheels/53/22/e8/004be7e776e11480a3d670f9dd2488a13794d4de4d6290afa5
#   Building wheel for PyMeta3 (pyproject.toml) ... done
#   Created wheel for PyMeta3: filename=pymeta3-0.5.1-py3-none-any.whl size=16518 sha256=63e29a41fd18cd8dfee77e4164b40929fca1ca624342684cc6dd0026e9fdc18d
#   Stored in directory: /home/anon/.cache/pip/wheels/8f/66/2c/fbe2a7aae963eb2d885051fe159fa8bf41cd198b14b5fbad59
#   Building wheel for lazy-object-proxy (pyproject.toml) ... done
#   Created wheel for lazy-object-proxy: filename=lazy_object_proxy-1.10.0-cp313-cp313-linux_x86_64.whl size=70160 sha256=ed86a3b792b7460f891ced43bc3da69c3be84b302722a48f638a8844cca5e167
#   Stored in directory: /home/anon/.cache/pip/wheels/5a/8a/a3/6b270f863df3862ab7e401bc1c97bebee5b87452b51189ebea
# Successfully built pybars4 PyMeta3 lazy-object-proxy
# Installing collected packages: PyMeta3, parse, ifaddr, zipp, wrapt, websockets, urllib3, typing-extensions, tqdm, sniffio, ruamel.yaml, rpds-py, rfc3339-validator, PyYAML, python-dotenv, PyJWT, pycparser, pybars4, propcache, pathable, numpy, multidict, more-itertools, MarkupSafe, lazy-object-proxy, jiter, isodate, idna, h11, google-crc32c, frozenlist, dnspython, distro, deprecation, defusedxml, charset-normalizer, chardet, certifi, av, attrs, annotated-types, aiohappyeyeballs, yarl, werkzeug, scipy, requests, referencing, pyee, pydantic-core, jinja2, importlib-metadata, httpcore, deprecated, cloudevents, cffi, anyio, aiosignal, aioice, pylibsrtp, pydantic, prance, opentelemetry-api, jsonschema-specifications, jsonschema-path, httpx, cryptography, azure-core, aiohttp, pyopenssl, pydantic-settings, opentelemetry-semantic-conventions, openai, jsonschema, opentelemetry-sdk, openapi-schema-validator, msal, aiortc, openapi-spec-validator, msal-extensions, openapi_core, azure-identity, semantic-kernel
# Successfully installed MarkupSafe-3.0.2 PyJWT-2.10.1 PyMeta3-0.5.1 PyYAML-6.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aioice-0.9.0 aiortc-1.11.0 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.9.0 attrs-25.3.0 av-14.2.0 azure-core-1.32.0 azure-identity-1.21.0 certifi-2025.1.31 cffi-1.17.1 chardet-5.2.0 charset-normalizer-3.4.1 cloudevents-1.11.0 cryptography-44.0.2 defusedxml-0.7.1 deprecated-1.2.18 deprecation-2.1.0 distro-1.9.0 dnspython-2.7.0 frozenlist-1.5.0 google-crc32c-1.7.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 ifaddr-0.2.0 importlib-metadata-8.6.1 isodate-0.7.2 jinja2-3.1.6 jiter-0.9.0 jsonschema-4.23.0 jsonschema-path-0.3.4 jsonschema-specifications-2024.10.1 lazy-object-proxy-1.10.0 more-itertools-10.6.0 msal-1.32.0 msal-extensions-1.3.1 multidict-6.2.0 numpy-2.2.4 openai-1.69.0 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.1 openapi_core-0.19.5 opentelemetry-api-1.31.1 opentelemetry-sdk-1.31.1 opentelemetry-semantic-conventions-0.52b1 parse-1.20.2 pathable-0.4.4 prance-23.6.21.0 propcache-0.3.1 pybars4-0.9.13 pycparser-2.22 pydantic-2.10.6 pydantic-core-2.27.2 pydantic-settings-2.8.1 pyee-13.0.0 pylibsrtp-0.11.0 pyopenssl-25.0.0 python-dotenv-1.1.0 referencing-0.36.2 requests-2.32.3 rfc3339-validator-0.1.4 rpds-py-0.24.0 ruamel.yaml-0.18.10 scipy-1.15.2 semantic-kernel-1.26.1 sniffio-1.3.1 tqdm-4.67.1 typing-extensions-4.13.0 urllib3-2.3.0 websockets-14.2 werkzeug-3.1.1 wrapt-1.17.2 yarl-1.18.3 zipp-3.21.0

# %%
# sk_connecting.py
import asyncio

import semantic_kernel as sk

selected_service = "OpenAI"
kernel = sk.Kernel()

service_id = None
if selected_service == "OpenAI":
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    api_key, org_id = sk.openai_settings_from_dot_env()
    service_id = "oai_chat_gpt"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
            ai_model_id="gpt-3.5-turbo-1106",
            api_key=api_key,
            org_id=org_id,
        ),
    )
elif selected_service == "AzureOpenAI":
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    deployment, api_key, endpoint = sk.azure_openai_settings_from_dot_env()
    service_id = "aoai_chat_completion"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
            deployment_name=deployment,
            endpoint=endpoint,
            api_key=api_key,
        ),
    )


# This function is currently broken
async def run_prompt():
    result = await kernel.invoke_prompt(prompt="recommend a movie about time travel")
    print(result)


# Use asyncio.run to execute the async function
asyncio.run(run_prompt())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 13
#      10 if selected_service == "OpenAI":
#      11     from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
# ---> 13     api_key, org_id = sk.openai_settings_from_dot_env()
#      14     service_id = "oai_chat_gpt"
#      15     kernel.add_service(
#      16         OpenAIChatCompletion(
#      17             service_id=service_id,
#    (...)     21         ),
#      22     )
#
# AttributeError: module 'semantic_kernel' has no attribute 'openai_settings_from_dot_env'

# %%
# sk_context_variables.py
import asyncio

import semantic_kernel as sk
import semantic_kernel.connectors.ai.open_ai as sk_oai
from semantic_kernel.prompt_template.input_variable import InputVariable

selected_service = "OpenAI"
kernel = sk.Kernel()

service_id = None
if selected_service == "OpenAI":
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    api_key, org_id = sk.openai_settings_from_dot_env()
    service_id = "oai_chat_gpt"
    model_id = "gpt-4-1106-preview"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
            ai_model_id=model_id,
            api_key=api_key,
            org_id=org_id,
        ),
    )
elif selected_service == "AzureOpenAI":
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    deployment, api_key, endpoint = sk.azure_openai_settings_from_dot_env()
    service_id = "aoai_chat_completion"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
            deployment_name=deployment,
            endpoint=endpoint,
            api_key=api_key,
        ),
    )

# set up the execution settings
if selected_service == "OpenAI":
    execution_settings = sk_oai.OpenAIChatPromptExecutionSettings(
        service_id=service_id,
        ai_model_id=model_id,
        max_tokens=2000,
        temperature=0.7,
    )
elif selected_service == "AzureOpenAI":
    execution_settings = sk_oai.OpenAIChatPromptExecutionSettings(
        service_id=service_id,
        ai_model_id=deployment,
        max_tokens=2000,
        temperature=0.7,
    )

prompt = """
system:

You have vast knowledge of everything and can recommend anything provided you are given the following criteria, the subject, genre, format and any other custom information.

user:
Please recommend a {{$format}} with the subject {{$subject}} and {{$genre}}. 
Include the following custom information: {{$custom}}
"""

prompt_template_config = sk.PromptTemplateConfig(
    template=prompt,
    name="tldr",
    template_format="semantic-kernel",
    input_variables=[
        InputVariable(
            name="format", description="The format to recommend", is_required=True
        ),
        InputVariable(
            name="suject", description="The subject to recommend", is_required=True
        ),
        InputVariable(
            name="genre", description="The genre to recommend", is_required=True
        ),
        InputVariable(
            name="custom",
            description="Any custom information to enhance the recommendation",
            is_required=True,
        ),
    ],
    execution_settings=execution_settings,
)

recommend_function = kernel.create_function_from_prompt(
    prompt_template_config=prompt_template_config,
    function_name="Recommend_Movies",
    plugin_name="Recommendation",
)


async def run_recommendation(
    subject="time travel", format="movie", genre="medieval", custom="must be a comedy"
):
    recommendation = await kernel.invoke(
        recommend_function,
        sk.KernelArguments(subject=subject, format=format, genre=genre, custom=custom),
    )
    print(recommendation)


# Use asyncio.run to execute the async function
asyncio.run(run_recommendation())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 15
#      12 if selected_service == "OpenAI":
#      13     from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
# ---> 15     api_key, org_id = sk.openai_settings_from_dot_env()
#      16     service_id = "oai_chat_gpt"
#      17     model_id = "gpt-4-1106-preview"
#
# AttributeError: module 'semantic_kernel' has no attribute 'openai_settings_from_dot_env'

# %% [markdown]
# ## Synergiging semantic and native functions:
#  - Semantic function: Encapsulate a prompt/profile and executes throught interaction with an llm.
#
# - Native Functions: Encapsulation of code that may perform anything from scraping websites to searching the web.
# - Both semantic and native functions can register as plugins/skills in SK kenel.

# %% [markdown]
# ## Creating/Reginstering semantic function
