# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %% [markdown]
# * **2.1 Rerun the first two cells in Section 2.1.2 and make sure you can see the game window and then close it.**

# %%
from utils.ttt_env import ttt
env = ttt()
env.reset()
env.render()

# %%
env.close()

# %% [markdown]
# * **2.2 Call the one_ttt_game() function and use ttt_manual as the first argument and
# ttt_think1 as the second argument. Play a game with the AI player manually.
# Create an opportunity for the AI player to win and see if it takes the winning
# move.**

# %%
from utils.ch02util import one_ttt_game, ttt_think1, ttt_manual

reward=one_ttt_game(ttt_think1, ttt_manual)
print(f"the game outcome is {reward}")
# Out:
# game state is
# [[0 0 0]
#  [0 0 0]
#  [0 1 0]]
# game state is
# [[ 1  0  0]
#  [ 0  0 -1]
#  [ 0  1  0]]
# game state is
# [[ 1  0 -1]
#  [ 0  0 -1]
#  [ 1  1  0]]
# the game outcome is 1

# %% [markdown]
# * **2.3 Modify the first code cell in Section 2.3.2 by letting the look-two-steps-ahead
# AI move second. Try to win the game yourself and see if the AI player can block
# your move.**

# %%
from utils.ch02util import ttt_think2
reward=one_ttt_game(ttt_think2, ttt_manual)
print(f"the game outcome is {reward}")
# Out:
# game state is
# [[0 0 0]
#  [0 0 1]
#  [0 0 0]]
# game state is
# [[ 0  0  1]
#  [ 0 -1  1]
#  [ 0  0  0]]
# game state is
# [[ 1  0  1]
#  [ 0 -1  1]
#  [ 0  0 -1]]
# game state is
# [[ 1 -1  1]
#  [ 0 -1  1]
#  [ 0  1 -1]]
# the game outcome is 0

# %% [markdown]
# * **2.4 Rerun the first cell in Section 2.4.2 and design your moves so that the AI player
# has an opportunity to create a double attack. See if it takes the opportunity
# and wins the game.**

# %%
from utils.ch02util import ttt_think3
reward=one_ttt_game(ttt_think3, ttt_manual)
print(f"the game outcome is {reward}")
# Out:
# game state is
# [[0 0 0]
#  [1 0 0]
#  [0 0 0]]
# game state is
# [[ 0  0  0]
#  [ 1  0  0]
#  [ 1 -1  0]]
# game state is
# [[-1  0  0]
#  [ 1  1  0]
#  [ 1 -1  0]]
# the game outcome is 1
